# %% [markdown]
# # Mushroom Decision Tree (Reduced Features) — Student Exercise
# ## Your Name:
# Kevin Nguyen## Date:
# 3/8/2026### In Blackboard you will submit your Github URL after saving your notebook to your class repository, AND a PDF of this notebook (in Colab, File . . . Print . . . PDF)
# This activity uses a simplified version of the Mushroom dataset to create a decision tree.
#
# ## Goals
# - Build a decision tree classifier
# - Interpret a confusion matrix and accuracy
# - Explain what the root and first-level nodes mean
# - Translate tree splits into plain English

# %% [markdown]
# ## 1️⃣ Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ## 2️⃣ Load the Mushroom dataset (code is completed for you)
# **Target:** `class`
# - `e` = edible which becomes 0 or not poisonous
# - `p` = poisonous which becomes 1

# %%
#note feature names, we will reduce these
mush = fetch_openml('mushroom', version=1, as_frame=True)
df = mush.frame.copy()
# rename the column
df = df.rename(columns={"bruises%3F": "bruises"})
df.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-color-above-ring  \
# 0         n          k           e  ...                      w
# 1         b          k           e  ...                      w
# 2         b          n           e  ...                      w
# 3         n          n           e  ...                      w
# 4         b          k           t  ...                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
#
#   spore-print-color population habitat class
# 0                 k          s       u     p
# 1                 n          n       g     e
# 2                 n          n       m     e
# 3                 k          s       u     p
# 4                 n          a       g     e
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 3️⃣ Use a reduced feature set (code is completed for you)
# These features are highly predictive and keep the tree readable. Note the class is mapped to 0 (edible) and 1 (poisonous).

# %%
features = ['odor', 'spore-print-color', 'gill-size', 'gill-color', 'bruises']

X = df[features]
y = df['class'].map({'e':0, 'p':1})

X.head(), y.value_counts()
# Out:
# (  odor spore-print-color gill-size gill-color bruises
#  0    p                 k         n          k       t
#  1    a                 n         b          k       t
#  2    l                 n         b          n       t
#  3    p                 k         n          n       t
#  4    n                 n         b          k       f,
#  class
#  0    4208
#  1    3916
#  Name: count, dtype: int64)

# %% [markdown]
# ## 4️⃣ One‑hot encode the categorical features (Add Code)
# Each category becomes a YES/NO column.

# %%
yes_no = pd.get_dummies(X)

yes_no.head()
# Out:
#    odor_a  odor_c  odor_f  odor_l  odor_m  odor_n  odor_p  odor_s  odor_y  \
# 0   False   False   False   False   False   False    True   False   False
# 1    True   False   False   False   False   False   False   False   False
# 2   False   False   False    True   False   False   False   False   False
# 3   False   False   False   False   False   False    True   False   False
# 4   False   False   False   False   False    True   False   False   False
#
#    spore-print-color_b  ...  gill-color_k  gill-color_n  gill-color_o  \
# 0                False  ...          True         False         False
# 1                False  ...          True         False         False
# 2                False  ...         False          True         False
# 3                False  ...         False          True         False
# 4                False  ...          True         False         False
#
#    gill-color_p  gill-color_r  gill-color_u  gill-color_w  gill-color_y  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    bruises_f  bruises_t
# 0      False       True
# 1      False       True
# 2      False       True
# 3      False       True
# 4       True      False
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 5️⃣ Train/test split (Add Code)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    yes_no, y, test_size=0.25, random_state=42
)

X_train.shape, X_test.shape
# Out:
# ((6093, 34), (2031, 34))

# %% [markdown]
# ## 6️⃣ Train a small decision tree (Add Code)

# %%
tree_m = DecisionTreeClassifier(max_depth=2, random_state=42)

tree_m.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %% [markdown]
# ## 7️⃣ Evaluate the model (Add Code)

# %%
y_pred = tree_m.predict(X_test)


print("Accuracy:", accuracy_score(y_test, y_pred))


print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))


print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9187592319054653
# Confusion Matrix:
# [[1040    0]
#  [ 165  826]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      1040
#            1       1.00      0.83      0.91       991
#
#     accuracy                           0.92      2031
#    macro avg       0.93      0.92      0.92      2031
# weighted avg       0.93      0.92      0.92      2031

# %% [markdown]
# ## 8️⃣ Visualize the decision tree (Add Code)

# %%
plt.figure(figsize=(20,10))

plot_tree(
    tree_m,
    feature_names=yes_no.columns,
    class_names=['edible','poisonous'],
    filled=True
)
# Out:
# [Text(0.5, 0.8333333333333334, 'odor_n <= 0.5\ngini = 0.499\nsamples = 6093\nvalue = [3168.0, 2925.0]\nclass = edible'),
#  Text(0.25, 0.5, 'bruises_t <= 0.5\ngini = 0.284\nsamples = 3421\nvalue = [586, 2835]\nclass = poisonous'),
#  Text(0.375, 0.6666666666666667, 'True  '),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 2442\nvalue = [0, 2442]\nclass = poisonous'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.481\nsamples = 979\nvalue = [586, 393]\nclass = edible'),
#  Text(0.75, 0.5, 'spore-print-color_r <= 0.5\ngini = 0.065\nsamples = 2672\nvalue = [2582, 90]\nclass = edible'),
#  Text(0.625, 0.6666666666666667, '  False'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.026\nsamples = 2616\nvalue = [2582, 34]\nclass = edible'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.0\nsamples = 56\nvalue = [0, 56]\nclass = poisonous')]

# %% [markdown]
# ## 9️⃣ Print IF–THEN rules (Add Code)

# %%
rules = export_text(tree_m, feature_names=list(yes_no.columns))
print(rules)
# Out:
# |--- odor_n <= 0.50
# |   |--- bruises_t <= 0.50
# |   |   |--- class: 1
# |   |--- bruises_t >  0.50
# |   |   |--- spore-print-color_h <= 0.50
# |   |   |   |--- odor_p <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- odor_p >  0.50
# |   |   |   |   |--- class: 1
# |   |   |--- spore-print-color_h >  0.50
# |   |   |   |--- class: 1
# |--- odor_n >  0.50
# |   |--- spore-print-color_r <= 0.50
# |   |   |--- gill-size_n <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- gill-size_n >  0.50
# |   |   |   |--- spore-print-color_w <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- spore-print-color_w >  0.50
# |   |   |   |   |--- class: 0
# |   |--- spore-print-color_r >  0.50
# |   |   |--- class: 1

# %% [markdown]
# ---
# # QUESTIONS TO ANSWER (provide answers in markdown)
# ### Confusion Matrix & Accuracy
# 1. What was the model accuracy? The model accuracy score was 0.9931068439192516.
# 2. How many poisonous mushrooms were correctly classified? 14
# 3. How many poisonous mushrooms were incorrectly predicted as edible? None
# 4. Why is misclassifying a poisonous mushroom more serious than misclassifying an edible one?Poisonous eatan can cost serious damage to the body.
#
# ### Understanding the Tree
# 5. What feature appears at the **root node**? Odor
# 6. What question is the root node asking in plain English?
# 7. Describe what the **left branch** and **right branch** mean. Left is true and right is false
#
# ### First Level Nodes
# 8. Look at the two nodes directly below the root.
#    - What feature does each split on? Gini and samples
#    - What question is each node asking? What is determining the mushroom.
#    - What does following the left vs right branch mean? Right means it does not meets the mode and left means its good.
#
# ### Interpretation
# 9. Choose ONE full path from the root to a leaf and translate it into plain English.
# 10. Based on the tree, what feature seems most important for predicting if a mushroom is poisonous? Odor
#
# ### Exploration
# 11. Change `max_depth` to 2. What changed? Tree became smaller and simple
# 12. Change `max_depth` to 5. What changed? Tree is more complex and larger
